# %% [markdown]
# # Görev 1:  List Comprehension yapısı kullanarak car_crashes verisindeki numeric değişkenlerin isimlerini büyük harfe çeviriniz ve başına NUM ekleyiniz. Beklenen çıktı: Numeric olmayan değişkenlerin de isimleri büyümeli. Tek bir list comprehension yapısı kullanılmalı.

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("car_crashes")
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium
# 0   18.8     7.332    5.640          18.048       15.040       784.55  \
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
["NUM_"+col.upper() if df[col].dtype=="float64" else col.upper() for col in df.columns]
# Out:
# ['NUM_TOTAL',
#  'NUM_SPEEDING',
#  'NUM_ALCOHOL',
#  'NUM_NOT_DISTRACTED',
#  'NUM_NO_PREVIOUS',
#  'NUM_INS_PREMIUM',
#  'NUM_INS_LOSSES',
#  'ABBREV']

# %% [markdown]
# # Görev 2:  List Comprehension yapısı kullanarak car_crashes verisinde isminde "no" barındırmayan değişkenlerin isimlerinin sonuna "FLAG" yazınız.

# %%
df.loc[2:5, df.columns.str.contains("no")]
# Out:
#    not_distracted  no_previous
# 2          15.624       17.856
# 3          21.056       21.280
# 4          10.920       10.680
# 5          10.744       12.920

# %%
[col.upper()+"_FLAG" if not col.startswith("no") else col.upper() for col in df.columns]
# Out:
# ['TOTAL_FLAG',
#  'SPEEDING_FLAG',
#  'ALCOHOL_FLAG',
#  'NOT_DISTRACTED',
#  'NO_PREVIOUS',
#  'INS_PREMIUM_FLAG',
#  'INS_LOSSES_FLAG',
#  'ABBREV_FLAG']

# %% [markdown]
# # Görev 3:  List Comprehension yapısı kullanarak aşağıda verilen değişken isimlerinden FARKLI olan değişkenlerin isimlerini seçiniz ve yeni bir dataframe oluşturunuz.

# %%
og_list=["abbrev", "no_previous"]

# %%
new_df = df.drop(og_list, axis=1)

# %%
new_df
# Out:
#     total  speeding  alcohol  not_distracted  ins_premium  ins_losses
# 0    18.8     7.332    5.640          18.048       784.55      145.08
# 1    18.1     7.421    4.525          16.290      1053.48      133.93
# 2    18.6     6.510    5.208          15.624       899.47      110.35
# 3    22.4     4.032    5.824          21.056       827.34      142.39
# 4    12.0     4.200    3.360          10.920       878.41      165.63
# 5    13.6     5.032    3.808          10.744       835.50      139.91
# 6    10.8     4.968    3.888           9.396      1068.73      167.02
# 7    16.2     6.156    4.860          14.094      1137.87      151.48
# 8     5.9     2.006    1.593           5.900      1273.89      136.05
# 9    17.9     3.759    5.191          16.468      1160.13      144.18
# 10   15.6     2.964    3.900          14.820       913.15      142.80
# 11   17.5     9.450    7.175          14.350       861.18      120.92
# ...
